# %%
##################################################################
# # ! Juno Magnetic Modelling using <Vector Potential> with <3 NNs>
# Table showing the RMS errors of `Spherical Harmonic Models` 
# computed at different subset of ***Juno Observation Orbits***
##################################################################
# %%
# # ! Setup
import numpy as np;
from LW_SH_Mag import *;
from LW_DataReadWrite import *;

# %%
# # ! SH Model Estimations of [Bx,By,Bz] at <Multiple Different Obs Dataset> using different <nmax>

# TODO ******************** Parameters ******************** #
cstRj=71492;        # Jupiter radius in km
GS2nT=1e5; # Gauss to nt
# TODO ********************** end ************************* #
FILEOBSs = ['input/Connerney_PJ01_33_4.0Rj.txt',      # <Connerney Obs dataset PJ01-33>
            'input/Juno_PJ01_33_4.0Rj.txt',           # <Our Obs dataset PJ01-33>
            'input/RawJuno_PJ01_33_4.0Rj.txt',        # <Raw Juno Obs dataset PJ01-33>
            'input/Juno_PJ01_50_4.0Rj.txt'];          # <Our Obs dataset PJ01-50>  
OBSNAMEs = ['CnyObs33',
          'OurObs33',
          'RawObs33',
          'OurObs50'];
FILESHs_INT = ['input/JRM33_I30.txt',
               'input/Bloxham_I32.txt'];
fileSH_ext = 'input/JRM33_E1.txt';
NMAXs = [30,32];    # Choose the expansion degree n
SHNAMEs = ['JRM33_I30E1','Bloxham_I32E1'];
pkNMAXs = [[18,30],[18,32]];
for iSH in range(len(FILESHs_INT)):
     nmax =NMAXs[iSH];
     shName = SHNAMEs[iSH];
     fileSH_int = FILESHs_INT[iSH];
     print('\n*********************\n',flush=True);
     print('RMS of %s Model evaluated at Juno <OBS>:'%(shName),flush=True);
     for n in range(nmax):
          if ((n+1) in pkNMAXs[iSH]):
               print('\033[41mn = %2d; \033[0m'%(n+1),end='',flush=True);
          else:
               print('n = %2d; '%(n+1),end='',flush=True);
          for iFILEOBS in range(len(FILEOBSs)):
               fileObs = FILEOBSs[iFILEOBS];
               nObs,PJ,Year,DD,xObs,yObs,zObs,bxObs,byObs,bzObs = LoadObsFile(fileObs,showinfo=False);
               refBNorm = np.sqrt(bxObs**2+byObs**2+bzObs**2);
               if ((n+1) in pkNMAXs[iSH]):
                    print('\033[41m%9s, \033[0m'%(OBSNAMEs[iFILEOBS]),end='',flush=True);
               else:
                    print('%9s, '%(OBSNAMEs[iFILEOBS]),end='',flush=True);
               estBx_I,estBy_I,estBz_I,_ = SHS_Bxyz(fileSH_int,n+1,cstRj,xObs,yObs,zObs,showinfo=False);
               estBx_E,estBy_E,estBz_E,_ = SHS_Bxyz(fileSH_ext,1,cstRj,xObs,yObs,zObs,showinfo=False,internal=False);
               estBx = estBx_I + estBx_E;
               estBy = estBy_I + estBy_E;
               estBz = estBz_I + estBz_E;
               estBNorm = np.sqrt(estBx**2+estBy**2+estBz**2); 
               rms = np.sqrt(np.mean((estBNorm-refBNorm)**2));
               if ((n+1) in pkNMAXs[iSH]):
                    print('\033[41mrms = %8.1f nT; \033[0m'%(GS2nT*rms),end='',flush=True);
               else:
                    print('rms = %8.1f nT; '%(GS2nT*rms),end='',flush=True);
          print('',flush=True); # <br>
# Out:
# *********************
#
# RMS of JRM33_I30E1 Model evaluated at Juno <OBS>:
# n =  1;  CnyObs33, rms =  67250.4 nT;  OurObs33, rms =  66956.2 nT;  RawObs33, rms =  67288.2 nT;  OurObs50, rms =  74734.1 nT;
# n =  2;  CnyObs33, rms =  49824.3 nT;  OurObs33, rms =  49634.2 nT;  RawObs33, rms =  49865.9 nT;  OurObs50, rms =  56869.4 nT;
# n =  3;  CnyObs33, rms =  38649.4 nT;  OurObs33, rms =  38572.7 nT;  RawObs33, rms =  38693.4 nT;  OurObs50, rms =  46367.1 nT;
# n =  4;  CnyObs33, rms =  30585.8 nT;  OurObs33, rms =  30534.6 nT;  RawObs33, rms =  30627.2 nT;  OurObs50, rms =  36114.8 nT;
# n =  5;  CnyObs33, rms =  20434.4 nT;  OurObs33, rms =  20403.2 nT;  RawObs33, rms =  20471.7 nT;  OurObs50, rms =  23847.0 nT;
# n =  6;  CnyObs33, rms =  14640.9 nT;  OurObs33, rms =  14572.4 nT;  RawObs33, rms =  14677.6 nT;  OurObs50, rms =  17315.9 nT;
# n =  7;  CnyObs33, rms =  11900.6 nT;  OurObs33, rms =  11852.0 nT;  RawObs33, rms =  11934.6 nT;  OurObs50, rms =  14137.6 nT;
# n =  8;  CnyObs33, rms =   8159.0 nT;  OurObs33, rms =   8129.9 nT;  RawObs33, rms =   8188.3 nT;  OurObs50, rms =  10365.3 nT;
# n =  9;  CnyObs33, rms =   6241.5 nT;  OurObs33, rms =   6223.0 nT;  RawObs33, rms =   6267.2 nT;  OurObs50, rms =   8065.0 nT;
# n = 10;  CnyObs33, rms =   4787.7 nT;  OurObs33, rms =   4780.4 nT;  RawObs33, rms =   4809.8 nT;  OurObs50, rms =   6188.1 nT;
# n = 11;  CnyObs33, rms =   3451.5 nT;  OurObs33, rms =   3445.3 nT;  RawObs33, rms =   3471.1 nT;  OurObs50, rms =   4650.4 nT;
# n = 12;  CnyObs33, rms =   2561.7 nT;  OurObs33, rms =   2560.6 nT;  RawObs33, rms =   2578.9 nT;  OurObs50, rms =   3526.9 nT;
# n = 13;  CnyObs33, rms =   1894.2 nT;  OurObs33, rms =   1893.3 nT;  RawObs33, rms =   1909.0 nT;  OurObs50, rms =   2687.3 nT;
# n = 14;  CnyObs33, rms =   1500.2 nT;  OurObs33, rms =   1496.5 nT;  RawObs33, rms =   1511.1 nT;  OurObs50, rms =   2047.0 nT;
# n = 15;  CnyObs33, rms =   1224.0 nT;  OurObs33, rms =   1220.0 nT;  RawObs33, rms =   1231.6 nT;  OurObs50, rms =   1670.5 nT;
# n = 16;  CnyObs33, rms =   1026.5 nT;  OurObs33, rms =   1023.3 nT;  RawObs33, rms =   1034.5 nT;  OurObs50, rms =   1429.9 nT;
# n = 17;  CnyObs33, rms =    911.6 nT;  OurObs33, rms =    908.1 nT;  RawObs33, rms =    919.1 nT;  OurObs50, rms =   1281.6 nT;
# n = 18;  CnyObs33, rms =    777.2 nT;  OurObs33, rms =    774.1 nT;  RawObs33, rms =    782.2 nT;  OurObs50, rms =   1121.9 nT;
# n = 19;  CnyObs33, rms =    670.5 nT;  OurObs33, rms =    668.5 nT;  RawObs33, rms =    678.3 nT;  OurObs50, rms =   1019.8 nT;
# n = 20;  CnyObs33, rms =    599.1 nT;  OurObs33, rms =    597.1 nT;  RawObs33, rms =    605.5 nT;  OurObs50, rms =    968.6 nT;
# n = 21;  CnyObs33, rms =    539.9 nT;  OurObs33, rms =    538.1 nT;  RawObs33, rms =    548.5 nT;  OurObs50, rms =    927.7 nT;
# n = 22;  CnyObs33, rms =    508.2 nT;  OurObs33, rms =    506.7 nT;  RawObs33, rms =    518.0 nT;  OurObs50, rms =    923.4 nT;
# n = 23;  CnyObs33, rms =    483.8 nT;  OurObs33, rms =    482.4 nT;  RawObs33, rms =    494.1 nT;  OurObs50, rms =    915.9 nT;
# n = 24;  CnyObs33, rms =    464.9 nT;  OurObs33, rms =    463.7 nT;  RawObs33, rms =    475.0 nT;  OurObs50, rms =    905.6 nT;
# n = 25;  CnyObs33, rms =    453.1 nT;  OurObs33, rms =    452.0 nT;  RawObs33, rms =    463.3 nT;  OurObs50, rms =    903.7 nT;
# n = 26;  CnyObs33, rms =    447.6 nT;  OurObs33, rms =    446.5 nT;  RawObs33, rms =    458.4 nT;  OurObs50, rms =    910.2 nT;
# n = 27;  CnyObs33, rms =    446.1 nT;  OurObs33, rms =    445.0 nT;  RawObs33, rms =    456.9 nT;  OurObs50, rms =    913.6 nT;
# n = 28;  CnyObs33, rms =    445.0 nT;  OurObs33, rms =    443.9 nT;  RawObs33, rms =    455.9 nT;  OurObs50, rms =    911.8 nT;
# n = 29;  CnyObs33, rms =    444.6 nT;  OurObs33, rms =    443.5 nT;  RawObs33, rms =    455.4 nT;  OurObs50, rms =    912.0 nT;
# n = 30;  CnyObs33, rms =    444.1 nT;  OurObs33, rms =    443.0 nT;  RawObs33, rms =    455.0 nT;  OurObs50, rms =    912.2 nT;
#
# *********************
#
# RMS of Bloxham_I32E1 Model evaluated at Juno <OBS>:
# n =  1;  CnyObs33, rms =  67250.3 nT;  OurObs33, rms =  66956.1 nT;  RawObs33, rms =  67288.0 nT;  OurObs50, rms =  74733.5 nT;
# n =  2;  CnyObs33, rms =  49826.1 nT;  OurObs33, rms =  49636.0 nT;  RawObs33, rms =  49867.7 nT;  OurObs50, rms =  56870.8 nT;
# n =  3;  CnyObs33, rms =  38648.3 nT;  OurObs33, rms =  38571.5 nT;  RawObs33, rms =  38692.2 nT;  OurObs50, rms =  46373.0 nT;
# n =  4;  CnyObs33, rms =  30576.1 nT;  OurObs33, rms =  30524.6 nT;  RawObs33, rms =  30617.5 nT;  OurObs50, rms =  36102.9 nT;
# n =  5;  CnyObs33, rms =  20436.3 nT;  OurObs33, rms =  20404.7 nT;  RawObs33, rms =  20473.6 nT;  OurObs50, rms =  23845.8 nT;
# n =  6;  CnyObs33, rms =  14636.5 nT;  OurObs33, rms =  14567.7 nT;  RawObs33, rms =  14673.2 nT;  OurObs50, rms =  17306.4 nT;
# n =  7;  CnyObs33, rms =  11897.7 nT;  OurObs33, rms =  11848.9 nT;  RawObs33, rms =  11931.8 nT;  OurObs50, rms =  14151.0 nT;
# n =  8;  CnyObs33, rms =   8131.4 nT;  OurObs33, rms =   8102.2 nT;  RawObs33, rms =   8160.5 nT;  OurObs50, rms =  10360.7 nT;
# n =  9;  CnyObs33, rms =   6245.0 nT;  OurObs33, rms =   6226.1 nT;  RawObs33, rms =   6270.6 nT;  OurObs50, rms =   8051.0 nT;
# n = 10;  CnyObs33, rms =   4815.9 nT;  OurObs33, rms =   4808.0 nT;  RawObs33, rms =   4838.2 nT;  OurObs50, rms =   6212.9 nT;
# n = 11;  CnyObs33, rms =   3439.5 nT;  OurObs33, rms =   3433.3 nT;  RawObs33, rms =   3458.9 nT;  OurObs50, rms =   4656.2 nT;
# n = 12;  CnyObs33, rms =   2483.7 nT;  OurObs33, rms =   2482.7 nT;  RawObs33, rms =   2499.8 nT;  OurObs50, rms =   3415.3 nT;
# n = 13;  CnyObs33, rms =   1847.5 nT;  OurObs33, rms =   1847.3 nT;  RawObs33, rms =   1862.3 nT;  OurObs50, rms =   2624.9 nT;
# n = 14;  CnyObs33, rms =   1463.0 nT;  OurObs33, rms =   1459.8 nT;  RawObs33, rms =   1474.8 nT;  OurObs50, rms =   2044.7 nT;
# n = 15;  CnyObs33, rms =   1153.1 nT;  OurObs33, rms =   1149.6 nT;  RawObs33, rms =   1161.4 nT;  OurObs50, rms =   1645.7 nT;
# n = 16;  CnyObs33, rms =    950.4 nT;  OurObs33, rms =    947.0 nT;  RawObs33, rms =    959.1 nT;  OurObs50, rms =   1421.6 nT;
# n = 17;  CnyObs33, rms =    826.6 nT;  OurObs33, rms =    823.5 nT;  RawObs33, rms =    834.9 nT;  OurObs50, rms =   1259.9 nT;
# n = 18;  CnyObs33, rms =    695.2 nT;  OurObs33, rms =    692.7 nT;  RawObs33, rms =    701.9 nT;  OurObs50, rms =   1099.0 nT;
# n = 19;  CnyObs33, rms =    616.7 nT;  OurObs33, rms =    614.5 nT;  RawObs33, rms =    623.8 nT;  OurObs50, rms =   1014.2 nT;
# n = 20;  CnyObs33, rms =    579.0 nT;  OurObs33, rms =    577.1 nT;  RawObs33, rms =    586.6 nT;  OurObs50, rms =    977.2 nT;
# n = 21;  CnyObs33, rms =    545.5 nT;  OurObs33, rms =    543.8 nT;  RawObs33, rms =    553.4 nT;  OurObs50, rms =    944.8 nT;
# n = 22;  CnyObs33, rms =    529.8 nT;  OurObs33, rms =    528.2 nT;  RawObs33, rms =    538.3 nT;  OurObs50, rms =    931.2 nT;
# n = 23;  CnyObs33, rms =    522.3 nT;  OurObs33, rms =    520.7 nT;  RawObs33, rms =    531.0 nT;  OurObs50, rms =    927.4 nT;
# n = 24;  CnyObs33, rms =    516.9 nT;  OurObs33, rms =    515.3 nT;  RawObs33, rms =    525.6 nT;  OurObs50, rms =    923.3 nT;
# n = 25;  CnyObs33, rms =    514.1 nT;  OurObs33, rms =    512.6 nT;  RawObs33, rms =    522.8 nT;  OurObs50, rms =    920.3 nT;
# n = 26;  CnyObs33, rms =    512.8 nT;  OurObs33, rms =    511.3 nT;  RawObs33, rms =    521.4 nT;  OurObs50, rms =    919.0 nT;
# n = 27;  CnyObs33, rms =    511.8 nT;  OurObs33, rms =    510.3 nT;  RawObs33, rms =    520.5 nT;  OurObs50, rms =    918.5 nT;
# n = 28;  CnyObs33, rms =    511.3 nT;  OurObs33, rms =    509.8 nT;  RawObs33, rms =    519.9 nT;  OurObs50, rms =    918.0 nT;
# n = 29;  CnyObs33, rms =    511.1 nT;  OurObs33, rms =    509.6 nT;  RawObs33, rms =    519.7 nT;  OurObs50, rms =    917.9 nT;
# n = 30;  CnyObs33, rms =    510.9 nT;  OurObs33, rms =    509.4 nT;  RawObs33, rms =    519.5 nT;  OurObs50, rms =    917.8 nT;
# n = 31;  CnyObs33, rms =    510.8 nT;  OurObs33, rms =    509.4 nT;  RawObs33, rms =    519.4 nT;  OurObs50, rms =    917.8 nT;
# n = 32;  CnyObs33, rms =    510.8 nT;  OurObs33, rms =    509.3 nT;  RawObs33, rms =    519.4 nT;  OurObs50, rms =    917.8 nT;

# %%
##################################################################
# # ! Juno Magnetic Modelling using <Vector Potential> with <3 NNs>
# Table showing the RMS errors of `Spherical Harmonic Models` 
# computed at different subset of ***Juno Observation Orbits***
##################################################################
# %%
# # ! Setup
import numpy as np;
from LW_SH_Mag import *;
from LW_DataReadWrite import *;

# %%
# %%

# # ! SH Model Estimations of [Bx,By,Bz] at <Multiple Different Obs Dataset> using different <nmax>

# TODO ******************** Parameters ******************** #
cstRj=71492;        # Jupiter radius in km
GS2nT=1e5;          # Gauss to nt
# TODO ********************** end ************************* #
FILEOBSs = ['input/Connerney_PJ01_33_4.0Rj.txt',      # <Connerney Obs dataset PJ01-33>
            'input/Juno_PJ01_33_4.0Rj.txt',           # <Our Obs dataset PJ01-33>
            'input/Juno_PJ01_50_4.0Rj.txt'];          # <Our Obs dataset PJ01-50>  
OBSNAMEs = ['CnyObs33',
          'OurObs33',
          'OurObs50'];
FILESHs_INT = ['input/JRM33_I30.txt',
               'input/Bloxham_I32.txt'];
fileSH_ext = 'input/JRM33_E1.txt';
NMAXs = [30,32];    # Choose the expansion degree n
SHNAMEs = ['JRM33_I30E1','Bloxham_I32E1'];
pkNMAXs = [[18,30],[18,32]];
for iSH in range(len(FILESHs_INT)):
     nmax =NMAXs[iSH];
     shName = SHNAMEs[iSH];
     fileSH_int = FILESHs_INT[iSH];
     print('\n*********************\n',flush=True);
     print('RMS of %s Model evaluated at Juno <OBS>:'%(shName),flush=True);
     for n in range(nmax):
          if ((n+1) in pkNMAXs[iSH]):
               print('\033[41mn = %2d; \033[0m'%(n+1),end='',flush=True);
          else:
               print('n = %2d; '%(n+1),end='',flush=True);
          for iFILEOBS in range(len(FILEOBSs)):
               fileObs = FILEOBSs[iFILEOBS];
               nObs,PJ,Year,DD,xObs,yObs,zObs,bxObs,byObs,bzObs = LoadObsFile(fileObs,showinfo=False);
               refBNorm = np.sqrt(bxObs**2+byObs**2+bzObs**2);
               if ((n+1) in pkNMAXs[iSH]):
                    print('\033[41m%9s, \033[0m'%(OBSNAMEs[iFILEOBS]),end='',flush=True);
               else:
                    print('%9s, '%(OBSNAMEs[iFILEOBS]),end='',flush=True);
               estBx_I,estBy_I,estBz_I,_ = SHS_Bxyz(fileSH_int,n+1,cstRj,xObs,yObs,zObs,showinfo=False);
               estBx_E,estBy_E,estBz_E,_ = SHS_Bxyz(fileSH_ext,1,cstRj,xObs,yObs,zObs,showinfo=False,internal=False);
               estBx = estBx_I + estBx_E;
               estBy = estBy_I + estBy_E;
               estBz = estBz_I + estBz_E;
               estBNorm = np.sqrt(estBx**2+estBy**2+estBz**2); 
               rms = np.sqrt(np.mean((estBNorm-refBNorm)**2));
               if ((n+1) in pkNMAXs[iSH]):
                    print('\033[41mrms = %8.1f nT; \033[0m'%(GS2nT*rms),end='',flush=True);
               else:
                    print('rms = %8.1f nT; '%(GS2nT*rms),end='',flush=True);
          print('',flush=True); # <br>
# Out:
# *********************
#
# RMS of JRM33_I30E1 Model evaluated at Juno <OBS>:
# n =  1;  CnyObs33, rms =  67234.6 nT;  OurObs33, rms =  66940.7 nT;  OurObs50, rms =  74718.4 nT;
# n =  2;  CnyObs33, rms =  49815.2 nT;  OurObs33, rms =  49625.3 nT;  OurObs50, rms =  56863.0 nT;
# n =  3;  CnyObs33, rms =  38648.8 nT;  OurObs33, rms =  38572.2 nT;  OurObs50, rms =  46371.0 nT;
# n =  4;  CnyObs33, rms =  30577.1 nT;  OurObs33, rms =  30526.1 nT;  OurObs50, rms =  36107.0 nT;
# n =  5;  CnyObs33, rms =  20425.5 nT;  OurObs33, rms =  20394.5 nT;  OurObs50, rms =  23836.8 nT;
# n =  6;  CnyObs33, rms =  14633.7 nT;  OurObs33, rms =  14565.4 nT;  OurObs50, rms =  17308.7 nT;
# n =  7;  CnyObs33, rms =  11892.0 nT;  OurObs33, rms =  11843.5 nT;  OurObs50, rms =  14130.7 nT;
# n =  8;  CnyObs33, rms =   8149.2 nT;  OurObs33, rms =   8120.2 nT;  OurObs50, rms =  10358.0 nT;
# n =  9;  CnyObs33, rms =   6230.9 nT;  OurObs33, rms =   6212.5 nT;  OurObs50, rms =   8056.5 nT;
# n = 10;  CnyObs33, rms =   4776.2 nT;  OurObs33, rms =   4768.9 nT;  OurObs50, rms =   6178.5 nT;
# n = 11;  CnyObs33, rms =   3437.1 nT;  OurObs33, rms =   3430.9 nT;  OurObs50, rms =   4639.8 nT;
# n = 12;  CnyObs33, rms =   2542.9 nT;  OurObs33, rms =   2541.8 nT;  OurObs50, rms =   3514.7 nT;
# n = 13;  CnyObs33, rms =   1868.8 nT;  OurObs33, rms =   1867.9 nT;  OurObs50, rms =   2670.9 nT;
# n = 14;  CnyObs33, rms =   1468.9 nT;  OurObs33, rms =   1465.1 nT;  OurObs50, rms =   2024.4 nT;
# n = 15;  CnyObs33, rms =   1186.3 nT;  OurObs33, rms =   1182.2 nT;  OurObs50, rms =   1643.1 nT;
# n = 16;  CnyObs33, rms =    980.5 nT;  OurObs33, rms =    977.2 nT;  OurObs50, rms =   1398.2 nT;
# n = 17;  CnyObs33, rms =    859.5 nT;  OurObs33, rms =    855.8 nT;  OurObs50, rms =   1246.5 nT;
# n = 18;  CnyObs33, rms =    715.8 nT;  OurObs33, rms =    712.6 nT;  OurObs50, rms =   1081.8 nT;
# n = 19;  CnyObs33, rms =    596.9 nT;  OurObs33, rms =    594.8 nT;  OurObs50, rms =    975.3 nT;
# n = 20;  CnyObs33, rms =    515.9 nT;  OurObs33, rms =    513.7 nT;  OurObs50, rms =    921.6 nT;
# n = 21;  CnyObs33, rms =    443.5 nT;  OurObs33, rms =    441.5 nT;  OurObs50, rms =    877.5 nT;
# n = 22;  CnyObs33, rms =    403.4 nT;  OurObs33, rms =    401.7 nT;  OurObs50, rms =    872.6 nT;
# n = 23;  CnyObs33, rms =    371.7 nT;  OurObs33, rms =    370.0 nT;  OurObs50, rms =    864.4 nT;
# n = 24;  CnyObs33, rms =    346.9 nT;  OurObs33, rms =    345.4 nT;  OurObs50, rms =    853.4 nT;
# n = 25;  CnyObs33, rms =    330.6 nT;  OurObs33, rms =    329.3 nT;  OurObs50, rms =    851.3 nT;
# n = 26;  CnyObs33, rms =    322.7 nT;  OurObs33, rms =    321.4 nT;  OurObs50, rms =    858.2 nT;
# n = 27;  CnyObs33, rms =    320.4 nT;  OurObs33, rms =    319.1 nT;  OurObs50, rms =    861.8 nT;
# n = 28;  CnyObs33, rms =    319.0 nT;  OurObs33, rms =    317.7 nT;  OurObs50, rms =    860.0 nT;
# n = 29;  CnyObs33, rms =    318.5 nT;  OurObs33, rms =    317.1 nT;  OurObs50, rms =    860.2 nT;
# n = 30;  CnyObs33, rms =    317.9 nT;  OurObs33, rms =    316.5 nT;  OurObs50, rms =    860.5 nT;
#
# *********************
#
# RMS of Bloxham_I32E1 Model evaluated at Juno <OBS>:
# n =  1;  CnyObs33, rms =  67234.5 nT;  OurObs33, rms =  66940.6 nT;  OurObs50, rms =  74717.8 nT;
# n =  2;  CnyObs33, rms =  49817.0 nT;  OurObs33, rms =  49627.1 nT;  OurObs50, rms =  56864.3 nT;
# n =  3;  CnyObs33, rms =  38647.8 nT;  OurObs33, rms =  38571.1 nT;  OurObs50, rms =  46377.0 nT;
# n =  4;  CnyObs33, rms =  30567.5 nT;  OurObs33, rms =  30516.3 nT;  OurObs50, rms =  36095.2 nT;
# n =  5;  CnyObs33, rms =  20427.6 nT;  OurObs33, rms =  20396.2 nT;  OurObs50, rms =  23835.7 nT;
# n =  6;  CnyObs33, rms =  14629.5 nT;  OurObs33, rms =  14560.9 nT;  OurObs50, rms =  17299.3 nT;
# n =  7;  CnyObs33, rms =  11889.4 nT;  OurObs33, rms =  11840.6 nT;  OurObs50, rms =  14144.2 nT;
# n =  8;  CnyObs33, rms =   8122.0 nT;  OurObs33, rms =   8092.8 nT;  OurObs50, rms =  10353.5 nT;
# n =  9;  CnyObs33, rms =   6234.9 nT;  OurObs33, rms =   6216.1 nT;  OurObs50, rms =   8042.7 nT;
# n = 10;  CnyObs33, rms =   4805.0 nT;  OurObs33, rms =   4797.2 nT;  OurObs50, rms =   6203.6 nT;
# n = 11;  CnyObs33, rms =   3425.9 nT;  OurObs33, rms =   3419.7 nT;  OurObs50, rms =   4646.1 nT;
# n = 12;  CnyObs33, rms =   2465.7 nT;  OurObs33, rms =   2464.7 nT;  OurObs50, rms =   3403.4 nT;
# n = 13;  CnyObs33, rms =   1823.2 nT;  OurObs33, rms =   1823.0 nT;  OurObs50, rms =   2609.0 nT;
# n = 14;  CnyObs33, rms =   1433.2 nT;  OurObs33, rms =   1430.1 nT;  OurObs50, rms =   2023.4 nT;
# n = 15;  CnyObs33, rms =   1115.8 nT;  OurObs33, rms =   1112.3 nT;  OurObs50, rms =   1619.2 nT;
# n = 16;  CnyObs33, rms =    904.2 nT;  OurObs33, rms =    900.8 nT;  OurObs50, rms =   1391.5 nT;
# n = 17;  CnyObs33, rms =    773.1 nT;  OurObs33, rms =    769.9 nT;  OurObs50, rms =   1226.1 nT;
# n = 18;  CnyObs33, rms =    631.1 nT;  OurObs33, rms =    628.4 nT;  OurObs50, rms =   1060.3 nT;
# n = 19;  CnyObs33, rms =    543.0 nT;  OurObs33, rms =    540.7 nT;  OurObs50, rms =    972.2 nT;
# n = 20;  CnyObs33, rms =    499.4 nT;  OurObs33, rms =    497.4 nT;  OurObs50, rms =    933.4 nT;
# n = 21;  CnyObs33, rms =    459.7 nT;  OurObs33, rms =    457.9 nT;  OurObs50, rms =    899.2 nT;
# n = 22;  CnyObs33, rms =    440.6 nT;  OurObs33, rms =    438.8 nT;  OurObs50, rms =    884.8 nT;
# n = 23;  CnyObs33, rms =    431.3 nT;  OurObs33, rms =    429.6 nT;  OurObs50, rms =    880.8 nT;
# n = 24;  CnyObs33, rms =    424.6 nT;  OurObs33, rms =    422.9 nT;  OurObs50, rms =    876.4 nT;
# n = 25;  CnyObs33, rms =    421.3 nT;  OurObs33, rms =    419.6 nT;  OurObs50, rms =    873.2 nT;
# n = 26;  CnyObs33, rms =    419.6 nT;  OurObs33, rms =    418.0 nT;  OurObs50, rms =    871.8 nT;
# n = 27;  CnyObs33, rms =    418.4 nT;  OurObs33, rms =    416.9 nT;  OurObs50, rms =    871.3 nT;
# n = 28;  CnyObs33, rms =    417.8 nT;  OurObs33, rms =    416.2 nT;  OurObs50, rms =    870.8 nT;
# n = 29;  CnyObs33, rms =    417.5 nT;  OurObs33, rms =    416.0 nT;  OurObs50, rms =    870.6 nT;
# n = 30;  CnyObs33, rms =    417.3 nT;  OurObs33, rms =    415.7 nT;  OurObs50, rms =    870.6 nT;
# n = 31;  CnyObs33, rms =    417.2 nT;  OurObs33, rms =    415.6 nT;  OurObs50, rms =    870.6 nT;
# n = 32;  CnyObs33, rms =    417.2 nT;  OurObs33, rms =    415.6 nT;  OurObs50, rms =    870.6 nT;
